# %%
from src.data.dataloader import CescoBidbConnection, CescoRodbConnection

bidb = CescoBidbConnection()
bidb.connect()

rodb = CescoRodbConnection()
rodb.connect()
# Out:
# 🚗 시스템 ODBC 드라이버: ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)', 'SQL Server Native Client 11.0', 'ODBC Driver 13 for SQL Server']
# ✅ 사용 가능한 드라이버 발견: ODBC Driver 13 for SQL Server
# 🔄 ODBC Driver 13 for SQL Server로 BIDB 연결 시도 중...
# ✅ CESCO BIDB 연결 성공!
# 🚗 시스템 ODBC 드라이버: ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)', 'SQL Server Native Client 11.0', 'ODBC Driver 13 for SQL Server']
# ✅ 사용 가능한 드라이버 발견: ODBC Driver 13 for SQL Server
# 🔄 ODBC Driver 13 for SQL Server로 연결 시도 중...
# ✅ CESCO RODB 연결 성공!
# True

# %%
with open("./assets/queries/rodb_query_train.sql", "r", encoding="utf-8") as file:
    rodb_query = file.read()

rodb_data = rodb.execute_query(rodb_query)
print(rodb_data.head())
# Out:
# ✅ RODB 쿼리 실행 성공! 결과: 1000행
#      고객코드                   고객명  유형대  유형중 유형대_명칭 유형중_명칭  대표자명     우편번호   담당부서  \
# 0  001170           (주)호남샤니양산지점  140  170   식품공장     기타   박해만  61069    16001
# 1  100170              고려대학교의료원  240  100     병원   종합병원   윤을식  02841    12045
# 2  100360           연세대학교세브란스빌딩  100  100     빌딩   일반빌딩   허동수  04527    12021
# 3  100410  (의)장산의료재단이춘택병원(식당포함)  240  110     병원   개인병원  최인성   16465    13011
# 4  100890           (주)농협사료경남지사  140  160   식품공장   사료공장   최당호  52057    15552
#
#       업태  ... 소분류_코드      소분류 중분류_코드   중분류 대분류_코드    대분류      등록일자  \
# 0  제조,도매  ...   C037      식료품   B013  식품공장   A003  일반사업체  20251027
# 1    의료업  ...   C055     종합병원   B007  의료시설   A003  일반사업체  20250923
# 2    부동산  ...   C013  대형오피스빌딩   B008    빌딩   A003  일반사업체  20250224
# 3     의료  ...   C049     일반병원   B007  의료시설   A003  일반사업체  20250122
# 4     제조  ...   C028       사료   B013  식품공장   A003  일반사업체  20250113
#
#                                                 미수내역  \
# 0  [{"미수년월":"201105","전월매출":1.250000000000000e+00...
# 1  [{"미수년월":"201105","전월매출":1.350000000000000e+00...
# 2  [{"미수년월":"201105","전월매출":8.700000000000000e+00...
# 3  [{"미수년월":"201105","전월매출":1.700000000000000e+00...
# 4  [{"미수년월":"201105","전월매출":3.680000000000000e+00...
#
#                                       contracts_info  \
# 0  [{"계약일련번호":"221215-22249-0005","계약일자":"2022121...
# 1  [{"계약일련번호":"190214-17045-0004","계약일자":"2019021...
# 2  [{"계약일련번호":"190227-13145-0023","계약일자":"2019022...
# 3  [{"계약일련번호":"200727-09178-0238","계약일자":"2020072...
# 4  [{"계약일련번호":"200924-14475-0104","계약일자":"2020092...
#
#                                  interaction_history
# 0  [{"event_type":"VOC","접수일시":"2021-12-10T00:00:...
# 1  [{"event_type":"VOC","접수일시":"2017-05-12T00:00:...
# 2  [{"event_type":"VOC","접수일시":"2018-08-16T00:00:...
# 3  [{"event_type":"VOC","접수일시":"2021-04-13T00:00:...
# 4  [{"event_type":"VOC","접수일시":"2018-09-12T00:00:...
#
# [5 rows x 32 columns]

# %%
rodb_data.head()
# Out:
#      고객코드                   고객명  유형대  유형중 유형대_명칭 유형중_명칭  대표자명     우편번호   담당부서  \
# 0  001170           (주)호남샤니양산지점  140  170   식품공장     기타   박해만  61069    16001
# 1  100170              고려대학교의료원  240  100     병원   종합병원   윤을식  02841    12045
# 2  100360           연세대학교세브란스빌딩  100  100     빌딩   일반빌딩   허동수  04527    12021
# 3  100410  (의)장산의료재단이춘택병원(식당포함)  240  110     병원   개인병원  최인성   16465    13011
# 4  100890           (주)농협사료경남지사  140  160   식품공장   사료공장   최당호  52057    15552
#
#       업태  ... 소분류_코드      소분류 중분류_코드   중분류 대분류_코드    대분류      등록일자  \
# 0  제조,도매  ...   C037      식료품   B013  식품공장   A003  일반사업체  20251027
# 1    의료업  ...   C055     종합병원   B007  의료시설   A003  일반사업체  20250923
# 2    부동산  ...   C013  대형오피스빌딩   B008    빌딩   A003  일반사업체  20250224
# 3     의료  ...   C049     일반병원   B007  의료시설   A003  일반사업체  20250122
# 4     제조  ...   C028       사료   B013  식품공장   A003  일반사업체  20250113
#
#                                                 미수내역  \
# 0  [{"미수년월":"201105","전월매출":1.250000000000000e+00...
# 1  [{"미수년월":"201105","전월매출":1.350000000000000e+00...
# 2  [{"미수년월":"201105","전월매출":8.700000000000000e+00...
# 3  [{"미수년월":"201105","전월매출":1.700000000000000e+00...
# 4  [{"미수년월":"201105","전월매출":3.680000000000000e+00...
#
#                                       contracts_info  \
# 0  [{"계약일련번호":"221215-22249-0005","계약일자":"2022121...
# 1  [{"계약일련번호":"190214-17045-0004","계약일자":"2019021...
# 2  [{"계약일련번호":"190227-13145-0023","계약일자":"2019022...
# 3  [{"계약일련번호":"200727-09178-0238","계약일자":"2020072...
# 4  [{"계약일련번호":"200924-14475-0104","계약일자":"2020092...
#
#                                  interaction_history
# 0  [{"event_type":"VOC","접수일시":"2021-12-10T00:00:...
# 1  [{"event_type":"VOC","접수일시":"2017-05-12T00:00:...
# 2  [{"event_type":"VOC","접수일시":"2018-08-16T00:00:...
# 3  [{"event_type":"VOC","접수일시":"2021-04-13T00:00:...
# 4  [{"event_type":"VOC","접수일시":"2018-09-12T00:00:...
#
# [5 rows x 32 columns]
